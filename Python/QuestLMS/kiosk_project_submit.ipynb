# %% [markdown]
# <a href="https://colab.research.google.com/github/blueberrycrumble/AIFFEL_quest_cr/blob/master/Python/QuestLMS/kiosk_project_submit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Kiosk:

    def __init__(self, menu, price):
        self.menu = menu
        self.price = price

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        self.order_menu = []  # 주문 리스트
        self.order_price = []  # 가격 리스트

        n = 0
        while n < 1 or len(self.menu) < n: # 입력값이 메뉴 길이보다 크거나 입력값이 1보다 작은 경우//즉 메뉴에 없는 번호
            n = int(input("음료를 번호를 입력하세요 : "))  # 음료 번호 입력 // 주문 유도 루프

            # 메뉴판에 있는 음료 번호일 때
            if 1 <= n and n <= len(self.menu): # 입력값이 1과 메뉴길이 사이일때
                # print('this is n:',n)
                # print('this is menu:',self.menu)
                # print('this is price:',self.price)
                # print('this is price length:',len(self.price))
                self.order_price.append(self.price[n-1])  # 가격 리스트에 추가합니다.
                self.price_sum = self.price[n-1]  # 합계 금액 # 다음 while 루프로 이동

                # 메뉴판에 없는 번호일 때
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.") # 입력값이 메뉴에 없으므로 while 루프 재가동

        # 음료 온도 물어보기
        t = 0  # 기본값
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3의 답을 입력하세요.
            if t == 1:
                self.temp = 'HOT'  # 주문 리스트에 메뉴 추가
            elif t == 2:
                self.temp = 'ICE'  # 주문 리스트에 메뉴 추가
            else:
                print("1과 2 중 하나를 입력하세요.\n") # t값이 1도 2도 아니므로 while 루프 재가동

        self.order_menu.append(self.temp + ' ' + self.menu[n-1])  # 주문 리스트에 추가합니다.
        # 문제 2-2의 답을 입력하세요.
        print(self.temp, self.menu[n-1], ' : ', self.price_sum, '원')  # 온도 속성을 추가한 주문 결과를 출력합니다.
        # 1차 주문 루프 끝 =================================================================

        # 추가 주문 또는 지불
        while n != 0:  # 지불을 선택하기 전까지 반복합니다.
            print()  # 줄 바꾸면서
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
            if n > 0 and n < len(self.menu) + 1:
                # 추가 음료 온도
                # 문제 2-4. 추가 음료의 온도를 입력받고, 가격 리스트, 주문 리스트, 합계 금액을 업데이트해보세요.
                t = 0
                while t != 1 and t != 2:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요: "))
                    if t == 1:
                        self.temp = 'HOT'
                    elif t == 2:
                        self.temp = 'ICE'
                    else:
                        print("1과 2 중 하나를 입력하세요.\n")

                self.price_sum = self.price[n-1]
                self.order_price.append(self.price[n-1])
                self.order_menu.append(self.temp + ' ' + self.menu[n-1])
                print('추가 주문 음료', self.temp, self.menu[n-1], ':', self.price_sum, '원\n', '합계 : ', self.order_price, '원')
            else :
                if n == 0 :  # 지불을 입력하면
                    print("주문이 완료되었습니다.")
                    print(f"주문 내역: {self.order_menu} \n주문 금액: {self.order_price}")  # 확인을 위한 리스트를 출력합니다.
                else :  # 없는 번호를 입력할 때
                    print("없는 메뉴입니다. 다시 주문해 주세요.")

    # 지불
    def pay(self):
        valid_input = ['1','2','cash','card']
        p = None

        while p not in valid_input:
                p = input('결제 수단을 선택해주세요.\n현금은 1번 또는 cash, 카드는 2번 또는 card를 입력해주세요:' )

                if  p in ['cash', '1']:
                    print('현금을 선택하셨습니다.\n직원을 호출하겠습니다.')

                elif p in ['card', '2']:
                    print('카드를 선택하셨습니다.\nIC칩 방향에 맞게 카드를 꽂아주세요.')

                else:
                    print('다시 결제를 시도해 주세요.')

    # 주문서 출력
    def table(self):

        # 외곽
        print('⟝' + '-' * 30 + '⟞')
        for i in range(5):
            print('|' + ' ' * 31 + '|')

        # 주문 상품명 : 해당 금액
        for i in range(len(self.order_menu)):
            print(self.order_menu[i], ' : ', self.order_price[i])

        print('합계 금액 :', sum(self.order_price))

        # 외곽
        for i in range(5):
            print('|' + ' ' * 31+ '|')
        print('⟝' + '-' * 30 + '⟞')

# %%
menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
price = [2000, 3000, 3000, 2500, 2500, 3000]

# 첫번째 객체 테스트
hesu_kiosk = Kiosk(menu,price)  # 객체 생성
hesu_kiosk.menu_print()  # 메뉴 출력
hesu_kiosk.menu_select()  # 주문
hesu_kiosk.pay()  # 지불
hesu_kiosk.table()  # 주문표 출력
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료를 번호를 입력하세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 1
# HOT mocha  :  3000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 4
# HOT 음료는 1을, ICE 음료는 2를 입력하세요: 2
# 추가 주문 음료 ICE yuza_tea : 2500 원
#  합계 :  [3000, 2500] 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 6
# HOT 음료는 1을, ICE 음료는 2를 입력하세요: 1
# 추가 주문 음료 HOT choco_latte : 3000 원
#  합계 :  [3000, 2500, 3000] 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다.
# 주문 내역: ['HOT mocha', 'ICE yuza_tea', 'HOT choco_latte']
# 주문 금액: [3000, 2500, 3000]
# 결제 수단을 선택해주세요.
# 현금은 1번 또는 cash, 카드는 2번 또는 card를 입력해주세요:cash
# 현금을 선택하셨습니다.
# 직원을 호출하겠습니다.
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# HOT mocha  :  3000
# ICE yuza_tea  :  2500
# HOT choco_latte  :  3000
# ...

# %%
# 메뉴가 하나뿐인 두번째 객체 테스트
janne_kiosk = Kiosk(['americano'],[5000])
janne_kiosk.menu_print()  # 메뉴 출력
janne_kiosk.menu_select()  # 주문
janne_kiosk.pay()  # 지불
janne_kiosk.table()  # 주문표 출력
# Out:
# 1 americano  :  5000 원
# 음료를 번호를 입력하세요 : 2
# 없는 메뉴입니다. 다시 주문해 주세요.
# 음료를 번호를 입력하세요 : 6
# 없는 메뉴입니다. 다시 주문해 주세요.
# 음료를 번호를 입력하세요 : 1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# ICE americano  :  5000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다.
# 주문 내역: ['ICE americano']
# 주문 금액: [5000]
# 결제 수단을 선택해주세요.
# 현금은 1번 또는 cash, 카드는 2번 또는 card를 입력해주세요:2
# 카드를 선택하셨습니다.
# IC칩 방향에 맞게 카드를 꽂아주세요.
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ICE americano  :  5000
# 합계 금액 : 5000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
